# %% [markdown]
# <a href="https://colab.research.google.com/github/k-venkatanagasai/DS-LAB/blob/main/4th%20exp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data=pd.Series(np.random.randn(6),index=[['a','a','b','b','c','c'],[1,2,1,2,1,2]])
print(data)
print(data['b'])
print(data[:,1])
# Out:
# a  1   -1.329419
#    2   -1.332497
# b  1    1.838783
#    2    0.080850
# c  1   -0.111352
#    2   -0.762327
# dtype: float64
# 1    1.838783
# 2    0.080850
# dtype: float64
# a   -1.329419
# b    1.838783
# c   -0.111352
# dtype: float64

# %%
import pandas as pd
import numpy as np
data=pd.Series(np.random.randn(6),index=[['a','a','b','b','c','c'],[1,2,1,2,1,2]])
df=data.unstack()
print(df)
print(df.stack())
# Out:
#           1         2
# a  2.134639  0.612250
# b  1.488411 -0.662424
# c  0.185085  1.073300
# a  1    2.134639
#    2    0.612250
# b  1    1.488411
#    2   -0.662424
# c  1    0.185085
#    2    1.073300
# dtype: float64

# %%
import pandas as pd
import numpy as np
df1=pd.DataFrame({'a':[1,np.nan,3],'b':[4,5,6]})
df2=pd.DataFrame({'a':[7,8,9],'b':[np.nan,11,12]})
merged=df1.combine_first(df2)
print(merged)
# Out:
#      a    b
# 0  1.0  4.0
# 1  8.0  5.0
# 2  3.0  6.0
